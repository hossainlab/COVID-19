# %%
import numpy as np 
import pandas as pd 
import geopandas as gpd 

import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
# Read data from live data sources 
url = 'https://www.worldometers.info/coronavirus/'

# %%
# Red html 
data = pd.read_html(url)

# %%
# Loop over data cases 
for data_cases in data:
    print(data_cases)
# Out:
#     Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0           China       80778      24.0       3158.0       22.0
# 1           Italy       10149       NaN        631.0        NaN
# 2            Iran        8042       NaN        291.0        NaN
# 3        S. Korea        7755     242.0         61.0        1.0
# 4          France        1784       NaN         33.0        NaN
# ..            ...         ...       ...          ...        ...
# 115      Mongolia           1       NaN          NaN        NaN
# 116     St. Barth           1       NaN          NaN        NaN
# 117          Togo           1       NaN          NaN        NaN
# 118        Turkey           1       NaN          NaN        NaN
# 119        Total:      119217     294.0       4299.0       25.0
#
#      TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop
# 0           61486.0        16134            4492.0              56.1
# 1            1004.0         8514             877.0             167.9
# 2            2731.0         5020               NaN              95.7
# 3             288.0         7406              54.0             151.3
# 4              12.0         1739              86.0              27.3
# ..              ...          ...               ...               ...
# 115             NaN            1               NaN               0.3
# 116             NaN            1               NaN               NaN
# 117             NaN            1               NaN               0.1
# 118             NaN            1               NaN               NaN
# 119         66561.0        48357            5747.0              15.3
#
# [120 rows x 9 columns]

# %%
# Check data type 
type(data_cases)
# Out:
# pandas.core.frame.DataFrame

# %%
# Take a look at dataset
data_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 9 columns):
# Country,Other       120 non-null object
# TotalCases          120 non-null int64
# NewCases            7 non-null float64
# TotalDeaths         27 non-null float64
# NewDeaths           5 non-null float64
# TotalRecovered      52 non-null float64
# ActiveCases         120 non-null int64
# Serious,Critical    38 non-null float64
# Tot Cases/1M pop    92 non-null float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 8.6+ KB

# %%
# Numerical Summary
data_cases.describe()
# Out:
#           TotalCases    NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# count     120.000000    7.000000    27.000000   5.000000       52.000000
# mean     1986.950000   84.000000   318.444444  10.000000     2560.038462
# std     13126.200637  126.821397  1003.965726  12.369317    12429.250284
# min         1.000000    2.000000     1.000000   1.000000        1.000000
# 25%         3.000000    5.000000     1.000000   1.000000        1.000000
# 50%        14.000000   16.000000     3.000000   1.000000        6.500000
# 75%        69.500000  133.000000    32.000000  22.000000       25.250000
# max    119217.000000  294.000000  4299.000000  25.000000    66561.000000
#
#        ActiveCases  Serious,Critical  Tot Cases/1M pop
# count    120.00000         38.000000         92.000000
# mean     805.95000        302.473684         12.493478
# std     4748.62775       1168.522577         28.081501
# min        0.00000          1.000000          0.100000
# 25%        3.00000          1.000000          0.475000
# 50%       13.00000          2.000000          1.950000
# 75%       60.50000          9.750000          8.350000
# max    48357.00000       5747.000000        167.900000

# %%
# Check missing data 
data_cases.isnull().sum()
# Out:
# Country,Other         0
# TotalCases            0
# NewCases            113
# TotalDeaths          93
# NewDeaths           115
# TotalRecovered       68
# ActiveCases           0
# Serious,Critical     82
# Tot Cases/1M pop     28
# dtype: int64

# %%
# Renaming
data_cases['Country,Other'].replace({'Country, Other': 'Country'}, inplace=True)

# %%
# Filling missing values 
data_cases.loc[:, 'TotalCases'].fillna(value=0, inplace=True)
data_cases.loc[:, 'NewCases'].fillna(value=0, inplace=True)
data_cases.loc[:, 'TotalDeaths'].fillna(value=0, inplace=True) 
data_cases.loc[:, 'NewDeaths'].fillna(value=0, inplace=True)
data_cases.loc[:, 'TotalRecovered'].fillna(value=0, inplace=True)
data_cases.loc[:, 'ActiveCases'].fillna(value=0, inplace=True)
data_cases.loc[:, 'Serious,Critical'].fillna(value=0, inplace=True)

# %%
# Type conversion
data_cases.astype({'TotalCases': 'int64', 'NewCases': 'int64', 'TotalDeaths': 'int64', 'NewDeaths': 'int64',
                   'TotalRecovered': 'int64', 'ActiveCases': 'int64', 'Serious,Critical': 'int64'
                  })
# Out:
#     Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0           China       80778        24         3158         22
# 1           Italy       10149         0          631          0
# 2            Iran        8042         0          291          0
# 3        S. Korea        7755       242           61          1
# 4          France        1784         0           33          0
# ..            ...         ...       ...          ...        ...
# 115      Mongolia           1         0            0          0
# 116     St. Barth           1         0            0          0
# 117          Togo           1         0            0          0
# 118        Turkey           1         0            0          0
# 119        Total:      119217       294         4299         25
#
#      TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop
# 0             61486        16134              4492              56.1
# 1              1004         8514               877             167.9
# 2              2731         5020                 0              95.7
# 3               288         7406                54             151.3
# 4                12         1739                86              27.3
# ..              ...          ...               ...               ...
# 115               0            1                 0               0.3
# 116               0            1                 0               NaN
# 117               0            1                 0               0.1
# 118               0            1                 0               NaN
# 119           66561        48357              5747              15.3
#
# [120 rows x 9 columns]

# %%
data_cases.groupby('TotalCases').sum()
# Out:
#             NewCases  TotalDeaths  NewDeaths  TotalRecovered  ActiveCases  \
# TotalCases
# 1                0.0          0.0        0.0             3.0           14
# 2                0.0          0.0        0.0             0.0           16
# 3                0.0          1.0        0.0             1.0           19
# 4                0.0          0.0        0.0             1.0            3
# 5                3.0          0.0        0.0             0.0           30
# ...              ...          ...        ...             ...          ...
# 7755           242.0         61.0        1.0           288.0         7406
# 8042             0.0        291.0        0.0          2731.0         5020
# 10149            0.0        631.0        0.0          1004.0         8514
# 80778           24.0       3158.0       22.0         61486.0        16134
# 119217         294.0       4299.0       25.0         66561.0        48357
#
#             Serious,Critical  Tot Cases/1M pop
# TotalCases
# 1                        0.0               1.1
# 2                        0.0               2.1
# 3                        1.0               2.2
# 4                        0.0               0.2
# 5                        1.0               2.8
# ...                      ...               ...
# 7755                    54.0             151.3
# 8042                     0.0              95.7
# 10149                  877.0             167.9
# 80778                 4492.0              56.1
# 119217                5747.0              15.3
#
# [64 rows x 7 columns]

# %%
data
# Out:
# [    Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
#  0           China       80757      22.0       3136.0       17.0
#  1           Italy        9172       0.0        463.0        0.0
#  2        S. Korea        7513      35.0         54.0        1.0
#  3            Iran        7161       0.0        237.0        0.0
#  4          France        1412       0.0         30.0        0.0
#  ..            ...         ...       ...          ...        ...
#  111        Panama           1       1.0          0.0        0.0
#  112      Paraguay           1       0.0          0.0        0.0
#  113     St. Barth           1       0.0          0.0        0.0
#  114          Togo           1       0.0          0.0        0.0
#  115        Total:      114458      96.0       4027.0       19.0
#
#       TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop
#  0           60095.0        17526            4794.0              56.1
#  1             724.0         7985             733.0             151.7
#  2             247.0         7212              36.0             146.5
#  3            2394.0         4530               0.0              85.3
#  4              12.0         1370              66.0              21.6
#  ..              ...          ...               ...               ...
#  111             0.0            1               0.0               0.2
#  112             0.0            1               0.0               0.1
#  113             0.0            1               0.0               NaN
#  114             0.0            1               0.0               0.1
#  115         64272.0        46159            5771.0              14.7
#
#  [116 rows x 9 columns]]

# %%
data_cases['TotalRecovered'].sum()
# Out:
# 128544.0

# %%
data_cases['TotalCases'].sum()
# Out:
# 238434
