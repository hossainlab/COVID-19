# %% [markdown]
# # WHO COVID-19 Data Analysis

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px 
from datetime import datetime, timedelta
import matplotlib.dates as mdates 
import plotly.graph_objs as go

# %% [markdown]
# ## Load Datasets

# %%
total_cases_df = pd.read_csv("./who_data/total_cases.csv")
total_deaths_df = pd.read_csv("./who_data/total_deaths.csv")
new_cases_df = pd.read_csv("./who_data/new_cases.csv")
new_deaths_df = pd.read_csv("./who_data/new_deaths.csv")

# %% [markdown]
# ## Exploring Total Cases

# %%
# Examine the dataset 
total_cases_df.head()
# Out:
#          date  Worldwide  Afghanistan  Albania  Algeria  Andorra  Argentina  \
# 0  2020-01-21        282          NaN      NaN      NaN      NaN        NaN
# 1  2020-01-22        314          NaN      NaN      NaN      NaN        NaN
# 2  2020-01-23        581          NaN      NaN      NaN      NaN        NaN
# 3  2020-01-24        846          NaN      NaN      NaN      NaN        NaN
# 4  2020-01-25       1320          NaN      NaN      NaN      NaN        NaN
#
#    Armenia  Australia  Austria  ...  Thailand  Togo  Tunisia  Turkey  Ukraine  \
# 0      NaN        NaN      NaN  ...         2   NaN      NaN     NaN      NaN
# 1      NaN        NaN      NaN  ...         2   NaN      NaN     NaN      NaN
# 2      NaN        NaN      NaN  ...         4   NaN      NaN     NaN      NaN
# 3      NaN        NaN      NaN  ...         4   NaN      NaN     NaN      NaN
# 4      NaN        3.0      NaN  ...         4   NaN      NaN     NaN      NaN
#
# ...

# %%
# Numerical Summary 
total_cases_df.describe()
# Out:
#            Worldwide  Afghanistan    Albania    Algeria  Andorra  Argentina  \
# count      52.000000    17.000000   4.000000  16.000000     10.0   9.000000
# mean    54497.846154     2.058824   6.000000   9.937500      1.0   8.222222
# std     38340.152995     1.819017   4.618802   8.820195      0.0   7.224572
# min       282.000000     1.000000   2.000000   1.000000      1.0   1.000000
# 25%     16682.500000     1.000000   2.000000   1.000000      1.0   1.000000
# 50%     51218.500000     1.000000   6.000000   8.500000      1.0   9.000000
# 75%     84089.750000     4.000000  10.000000  17.750000      1.0  12.000000
# max    125048.000000     7.000000  10.000000  25.000000      1.0  19.000000
#
#        Armenia  Australia     Austria  Azerbaijan  ...   Thailand  Togo  \
# count     11.0    48.0000   16.000000   12.000000  ...  52.000000   6.0
# mean       1.0    27.1250   66.000000    6.000000  ...  30.807692   1.0
# ...

# %%
# Missing data check 
total_cases_df.isnull().sum()
# Out:
# date                     0
# Worldwide                0
# Afghanistan             35
# Albania                 48
# Algeria                 36
#                         ..
# United Arab Emirates     8
# United Kingdom          11
# United States            2
# Vatican                 46
# Vietnam                  3
# Length: 121, dtype: int64

# %%
# Data Cleaning 
cols = total_cases_df.keys()
print(cols)
# Out:
# Index(['date', 'Worldwide', 'Afghanistan', 'Albania', 'Algeria', 'Andorra',
#        'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Thailand', 'Togo', 'Tunisia', 'Turkey', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States', 'Vatican',
#        'Vietnam'],
#       dtype='object', length=121)

# %% [markdown]
# ## WHO Data Sources
# - Total Confirmed Cases: https://cowid.netlify.com/data/total_cases.csv
# - Total Deaths Cases: etlify.com/data/total_deaths.csv
# - New Cases:https://cowid.netlify.com/data/new_cases.csv
# - New Deaths Cases: https://cowid.netlify.com/data/new_deaths.csv
# - Full Dataset: http://cowid.netlify.com/data/full_data.csv

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
